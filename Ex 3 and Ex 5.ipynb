# %%
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

# %%
data = pd.read_csv("E:\SEM-7\DA_LAb\dataset\SP.csv") 
rs=data.head()
rs
# Out:
#    gender     race  parental_education         lunch    lunch.1  math_score  \
# 0  female  group B   bachelor's degree      standard       none          72
# 1  female  group C        some college      standard  completed          69
# 2  female  group B     master's degree      standard       none          90
# 3    male  group A  associate's degree  free/reduced       none          47
# 4    male  group C        some college      standard       none          76
#
#    reading_score  writing_score
# 0             72             74
# 1             90             88
# 2             95             93
# 3             57             44
# 4             78             75

# %%
mean1 = data['math_score'].mean()

# %%
print ('Mean : ' + str(mean1))
# Out:
# Mean : 66.089

# %%
slice = data.iloc[:,[5, 6]]

# %%
bp = slice.boxplot(column='math_score', by='reading_score')
axes = pl.gca()
axes.set_xlim([0,50])
axes.set_ylim([0,50])
pl.show()

# %%
import scipy
from scipy import stats
scipy.stats.hmean(data.loc[:,"writing_score"])
# Out:
# 63.70381780639471

# %%
score=data.writing_score
score.mean()
# Out:
# 68.054

# %%
scipy.stats.mstats.gmean(score, axis=0)
# Out:
# 66.11476733866351

# %%
scipy.stats.iqr(data.reading_score)
# Out:
# 20.0

# %%
pl.boxplot(data.math_score)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x77a238c5f8>,
#   <matplotlib.lines.Line2D at 0x77a238ca90>],
#  'caps': [<matplotlib.lines.Line2D at 0x77a238ceb8>,
#   <matplotlib.lines.Line2D at 0x77a2397320>],
#  'boxes': [<matplotlib.lines.Line2D at 0x77a238c4a8>],
#  'medians': [<matplotlib.lines.Line2D at 0x77a2397748>],
#  'fliers': [<matplotlib.lines.Line2D at 0x77a2397b70>],
#  'means': []}

# %%
import seaborn as sns
his=sns.countplot(x="reading_score",data=data.sample(30))

# %%
import matplotlib.pyplot as plt
m=data.math_score.sample(30)
n=data.reading_score.sample(30)
plt.pie(n,labels=m,autopct='%.1f%%',startangle=90)
plt.show()

# %%
pl.bar(data.math_score.sample(30),data.reading_score.sample(30))
pl.show()

# %%
import seaborn as sns
his=sns.countplot(x="math_score",data=data.sample(30))

# %%
sns.boxplot(x="gender",y="math_score",data=data)

# %%
get_ipython().run_line_magic('matplotlib', 'inline')
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %%
x = data.writing_score
y = data.reading_score

pl.scatter(x,y, label='outlier', color='k', s=10, marker="o")

pl.xlabel('x')
pl.ylabel('y')
pl.title('Scatter plot for math and reading score')
pl.legend()
pl.show()
